# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os

# Ruta del conjunto de datos
dataset_path = '/content/drive/MyDrive/dataset'

# Verifica la cantidad de imágenes en cada clase
for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)
    if os.path.isdir(folder_path):
        images = os.listdir(folder_path)
        print(f"{folder}: {len(images)} imágenes")
# Out:
# Ulises: 130 imágenes
# Juan: 130 imágenes
# Joel: 130 imágenes

# %%
import os
from PIL import Image

# Ruta del conjunto de datos
DATASET_PATH = '/content/drive/MyDrive/dataset'
IMAGE_SIZE = (224, 224)
VALID_EXTENSIONS = ['.jpg', '.jpeg', '.png']  # Formatos permitidos

def check_and_clean_images(dataset_path, image_size=IMAGE_SIZE, valid_extensions=VALID_EXTENSIONS):
    """
    Verifica que las imágenes en el conjunto de datos tengan el formato correcto y las dimensiones adecuadas.
    Recorta las imágenes para asegurarse de que tengan el tamaño adecuado y guarda las imágenes válidas.

    Args:
        dataset_path (str): Ruta al directorio del dataset
        image_size (tuple): Tamaño deseado para las imágenes (altura, ancho)
        valid_extensions (list): Formatos de imagen permitidos

    Returns:
        None
    """
    cleaned_data_path = '/content/drive/MyDrive/cleaned_dataset'

    # Crea la ruta para guardar las imágenes limpias
    if not os.path.exists(cleaned_data_path):
        os.makedirs(cleaned_data_path)

    # Recorre las carpetas de clases
    for class_folder in os.listdir(dataset_path):
        class_folder_path = os.path.join(dataset_path, class_folder)

        if os.path.isdir(class_folder_path):
            cleaned_class_folder = os.path.join(cleaned_data_path, class_folder)
            if not os.path.exists(cleaned_class_folder):
                os.makedirs(cleaned_class_folder)

            # Recorre las imágenes dentro de cada clase
            for image_name in os.listdir(class_folder_path):
                image_path = os.path.join(class_folder_path, image_name)

                # Verifica la extensión de la imagen
                if any(image_name.lower().endswith(ext) for ext in valid_extensions):
                    try:
                        # Abre la imagen
                        with Image.open(image_path) as img:
                            # Recorta o redimensiona la imagen si es necesario
                            img = img.resize(image_size)

                            # Guarda la imagen limpia en el nuevo directorio
                            cleaned_image_path = os.path.join(cleaned_class_folder, image_name)
                            img.save(cleaned_image_path)
                            print(f"Imagen guardada: {cleaned_image_path}")
                    except Exception as e:
                        print(f"Error al procesar la imagen {image_path}: {e}")
                else:
                    print(f"Formato de imagen no permitido: {image_path}")

# Llamada a la función para verificar y limpiar las imágenes
check_and_clean_images(DATASET_PATH)
# Out:
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.39 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.40 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.40 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.40 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.40 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.41 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.41 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.41 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.41 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.42 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.42 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.42 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.42 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.43 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.43 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.44 PM (5).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.45 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.45 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.45 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.46 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.46 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.46 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.47 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.47 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.47 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.47 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.48 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.48 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.48 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.49 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.50 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.50 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.50 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.51 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.52 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.52 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.53 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.54 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.55 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.55 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.56 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.56 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.57 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.57 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.57 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.57 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.58 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.59 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.46.59 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.01 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.01 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.02 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.03 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.04 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.04 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.05 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.05 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.06 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.08 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.08 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.09 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.10 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.10 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.11 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.11 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.11 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.12 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.12 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.12 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.14 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.14 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.15 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.15 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.16 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.16 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.17 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.17 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.18 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.18 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.19 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.19 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.20 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.21 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.27 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/WhatsApp Image 2024-12-06 at 2.47.27 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/1733514001933.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/1733514001940.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/1733514001926.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.26 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.26 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.24 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.27 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.26 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.17 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.14 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.11 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.06 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.02 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.57 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.55 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.51 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.48 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.46 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.44 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.43 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.41 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.40 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.24 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.21 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.17 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.14 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.11 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.08 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.24 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.20 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.47 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.48 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.58 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.45 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.42 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.56 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.44 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.40 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.46.52 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Ulises/Copia de WhatsApp Image 2024-12-06 at 2.47.03 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.15 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/0fac5586-e8bc-425e-a0fb-6191a429279f.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.57 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.58 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.58 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.58 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.58 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.59 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.59 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.52.59 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.00 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.00 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.00 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.00 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.01 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.01 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.02 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.02 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.02 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.02 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.03 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.03 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.03 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.03 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.03 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.04 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.04 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.04 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.04 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.05 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.05 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.05 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.05 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.06 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.06 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.06 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.06 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.07 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.08 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.08 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.08 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.09 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.09 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.09 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.09 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.10 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.10 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.10 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.10 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.11 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.11 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.11 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.11 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.11 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.12 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.12 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.12 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.12 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.12 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.13 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.13 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.13 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.13 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.13 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.14 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.14 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.14 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.14 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.14 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/WhatsApp Image 2024-12-06 at 2.53.15 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.02 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.02 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.02 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.01 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.01 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.00 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.03 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.03 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.03 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.03 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.03 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.02 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.05 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.05 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.04 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.04 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.04 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.04 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.09 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.12 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.11 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.11 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.12 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.10 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.11 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.11 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.13 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.09 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.10 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.10 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.08 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.05 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.10 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.08 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.08 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.05 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.09 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.13 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.13 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.15 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.12 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.13 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.12 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.15 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (4).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.11 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.06 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.06 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.09 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.12 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.06 PM (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.13 PM (3).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.07 PM.jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.06 PM (2).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (4) (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Juan/Copia de WhatsApp Image 2024-12-06 at 2.53.14 PM (3) (1).jpeg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145238.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145238_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145239.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145240.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145241.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145242.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145245.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145246.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145246_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145247.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145248.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145249.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145250.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_145251.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150901_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150901.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150903.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150902.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150904.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150908.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150909.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150909_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150910_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150910.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150911.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150912.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150913.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150914.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150914_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150915.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150915_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150917.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150916.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150918.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150918_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150919.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150920.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150920_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150921.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150922.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150923.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150924.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150925.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150924_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150928.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/IMG_20241127_150930_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150926.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150925.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150920.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150931.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150923.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150922.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150921.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150921 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150926 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150931 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930_1 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150925 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927_1 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150928.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150924.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150929.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150924_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150922 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150923 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150909_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150901_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150910_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150910.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150908.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150909.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150902.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150903.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150901.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_145251.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150925 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150931 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150921 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150923 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150926 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150920 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150922 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150926 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150918.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150917.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150927_1 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150923 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150922 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150921 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150924 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150925 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150918_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150919.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150929 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150928 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150920 (2).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150924_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150920_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150930_1 (3).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_145250.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150912.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150914_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150911.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150914.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150913.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150915_1.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150904.jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150909 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150910 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150914 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150917 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150909_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150918_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150913 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150914_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150910_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150915_1 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150918 (1).jpg
# Imagen guardada: /content/drive/MyDrive/cleaned_dataset/Joel/Copia de IMG_20241127_150919 (1).jpg

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Configuración de rutas
DATASET_PATH = '/content/drive/MyDrive/cleaned_dataset'
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32

def prepare_dataset(dataset_path):
    """
    Prepara el dataset para entrenamiento

    Args:
        dataset_path (str): Ruta al directorio del dataset

    Returns:
        tuple: Generadores de datos de entrenamiento y validación
    """
    # Generador de datos con aumento de imagen
    data_generator = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        validation_split=0.2  # 20% para validación
    )

    # Generador de datos de entrenamiento
    train_generator = data_generator.flow_from_directory(
        dataset_path,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='training'
    )

    # Generador de datos de validación
    validation_generator = data_generator.flow_from_directory(
        dataset_path,
        target_size=IMAGE_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='categorical',
        subset='validation'
    )

    return train_generator, validation_generator

# Uso
train_data, val_data = prepare_dataset(DATASET_PATH)
num_classes = len(train_data.class_indices)
print(f"Clases detectadas: {train_data.class_indices}")
# Out:
# Found 312 images belonging to 3 classes.
# Found 78 images belonging to 3 classes.
# Clases detectadas: {'Joel': 0, 'Juan': 1, 'Ulises': 2}

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization, Input
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import MobileNetV2

def create_improved_facial_recognition_model(input_shape, num_classes):
    """
    Crea un modelo CNN mejorado para reconocimiento facial usando transfer learning

    Args:
        input_shape (tuple): Dimensiones de la imagen de entrada
        num_classes (int): Número de clases a clasificar

    Returns:
        tf.keras.Model: Modelo CNN compilado
    """
    # Base pre-entrenada
    base_model = MobileNetV2(
        input_shape=input_shape,
        include_top=False,
        weights='imagenet',
        pooling='avg'
    )

    # Descongelar más capas del modelo base
    base_model.trainable = True
    fine_tune_at = 100  # Selecciona cuántas capas descongelar
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    # Modelo secuencial
    model = Sequential([
        # Capa de entrada
        Input(shape=input_shape),

        # Base pre-entrenada
        base_model,

        # Capas personalizadas
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),

        Dense(256, activation='relu'),
        BatchNormalization(),
        Dropout(0.4),

        # Capa de salida
        Dense(num_classes, activation='softmax')
    ])

    # Compilación del modelo
    model.compile(
        optimizer=Adam(learning_rate=1e-5),  # Usar una tasa de aprendizaje más baja
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

def create_data_augmentation():
    """
    Crear generador de datos con aumento más agresivo

    Returns:
        ImageDataGenerator: Generador de datos aumentados
    """
    return ImageDataGenerator(
        rescale=1./255,
        rotation_range=40,  # Aumentar el rango de rotación
        width_shift_range=0.3,  # Aumentar el desplazamiento horizontal
        height_shift_range=0.3,  # Aumentar el desplazamiento vertical
        shear_range=0.3,  # Aumentar la deformación
        zoom_range=0.3,  # Aumentar el rango de zoom
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='nearest',
        validation_split=0.2
    )

# Configuración de hiperparámetros
INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = len(train_data.class_indices)

# Crear generador de datos
data_generator = create_data_augmentation()

# Crear modelo
model = create_improved_facial_recognition_model(INPUT_SHAPE, NUM_CLASSES)

# Callbacks para optimización
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,  # Reducir más la tasa de aprendizaje cuando no haya mejoras
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Guardar el mejor modelo
model_checkpoint = ModelCheckpoint(
    'best_facial_recognition_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

# Entrenamiento del modelo
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=50,
    callbacks=[reduce_lr, early_stop, model_checkpoint]
)

# Evaluar el modelo
evaluation = model.evaluate(val_data)
print(f"Precisión de validación: {evaluation[1]*100:.2f}%")

# Guardar modelo final
model.save('facial_recognition_model.keras')
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2878 - loss: 2.2084
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 54s 3s/step - accuracy: 0.2914 - loss: 2.1828 - val_accuracy: 0.3333 - val_loss: 1.1448 - learning_rate: 1.0000e-05
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3603 - loss: 1.7832
# Epoch 2: val_accuracy improved from 0.33333 to 0.37179, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.3590 - loss: 1.7844 - val_accuracy: 0.3718 - val_loss: 1.1289 - learning_rate: 1.0000e-05
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4980 - loss: 1.3254
# Epoch 3: val_accuracy did not improve from 0.37179
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.5008 - loss: 1.3206 - val_accuracy: 0.3718 - val_loss: 1.0832 - learning_rate: 1.0000e-05
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5958 - loss: 1.1167
# Epoch 4: val_accuracy improved from 0.37179 to 0.41026, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.5955 - loss: 1.1144 - val_accuracy: 0.4103 - val_loss: 1.0461 - learning_rate: 1.0000e-05
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6155 - loss: 0.8972
# Epoch 5: val_accuracy improved from 0.41026 to 0.46154, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.6169 - loss: 0.8965 - val_accuracy: 0.4615 - val_loss: 1.0433 - learning_rate: 1.0000e-05
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6710 - loss: 0.7766
# Epoch 6: val_accuracy did not improve from 0.46154
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.6723 - loss: 0.7732 - val_accuracy: 0.4487 - val_loss: 1.0201 - learning_rate: 1.0000e-05
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7256 - loss: 0.7012
# Epoch 7: val_accuracy improved from 0.46154 to 0.48718, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.7264 - loss: 0.6978 - val_accuracy: 0.4872 - val_loss: 0.9814 - learning_rate: 1.0000e-05
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7579 - loss: 0.6480
# Epoch 8: val_accuracy improved from 0.48718 to 0.53846, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 3s/step - accuracy: 0.7607 - loss: 0.6399 - val_accuracy: 0.5385 - val_loss: 0.9164 - learning_rate: 1.0000e-05
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7727 - loss: 0.4797
# Epoch 9: val_accuracy improved from 0.53846 to 0.65385, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.7750 - loss: 0.4777 - val_accuracy: 0.6538 - val_loss: 0.8903 - learning_rate: 1.0000e-05
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8337 - loss: 0.4254
# Epoch 10: val_accuracy did not improve from 0.65385
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.8334 - loss: 0.4243 - val_accuracy: 0.6154 - val_loss: 0.9217 - learning_rate: 1.0000e-05
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8581 - loss: 0.4084
# Epoch 11: val_accuracy did not improve from 0.65385
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.8576 - loss: 0.4083 - val_accuracy: 0.6538 - val_loss: 0.8443 - learning_rate: 1.0000e-05
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8676 - loss: 0.3838
# Epoch 12: val_accuracy improved from 0.65385 to 0.69231, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.8662 - loss: 0.3831 - val_accuracy: 0.6923 - val_loss: 0.8083 - learning_rate: 1.0000e-05
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9333 - loss: 0.2187
# Epoch 13: val_accuracy improved from 0.69231 to 0.71795, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9306 - loss: 0.2226 - val_accuracy: 0.7179 - val_loss: 0.7821 - learning_rate: 1.0000e-05
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9195 - loss: 0.2638
# Epoch 14: val_accuracy improved from 0.71795 to 0.78205, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9201 - loss: 0.2617 - val_accuracy: 0.7821 - val_loss: 0.7213 - learning_rate: 1.0000e-05
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9382 - loss: 0.2484
# Epoch 15: val_accuracy improved from 0.78205 to 0.87179, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9388 - loss: 0.2453 - val_accuracy: 0.8718 - val_loss: 0.6179 - learning_rate: 1.0000e-05
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9310 - loss: 0.2048
# Epoch 16: val_accuracy did not improve from 0.87179
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9297 - loss: 0.2079 - val_accuracy: 0.8077 - val_loss: 0.6554 - learning_rate: 1.0000e-05
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9104 - loss: 0.2620
# Epoch 17: val_accuracy improved from 0.87179 to 0.88462, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9116 - loss: 0.2580 - val_accuracy: 0.8846 - val_loss: 0.5616 - learning_rate: 1.0000e-05
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9566 - loss: 0.1664
# Epoch 18: val_accuracy did not improve from 0.88462
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9550 - loss: 0.1677 - val_accuracy: 0.8333 - val_loss: 0.6178 - learning_rate: 1.0000e-05
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9389 - loss: 0.2181
# Epoch 19: val_accuracy improved from 0.88462 to 0.91026, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9395 - loss: 0.2158 - val_accuracy: 0.9103 - val_loss: 0.5351 - learning_rate: 1.0000e-05
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9611 - loss: 0.1317
# Epoch 20: val_accuracy did not improve from 0.91026
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9612 - loss: 0.1315 - val_accuracy: 0.8590 - val_loss: 0.5114 - learning_rate: 1.0000e-05
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9401 - loss: 0.1854
# Epoch 21: val_accuracy did not improve from 0.91026
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9412 - loss: 0.1824 - val_accuracy: 0.8462 - val_loss: 0.5499 - learning_rate: 1.0000e-05
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9737 - loss: 0.1096
# Epoch 22: val_accuracy did not improve from 0.91026
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0.9741 - loss: 0.1085 - val_accuracy: 0.8205 - val_loss: 0.5445 - learning_rate: 1.0000e-05
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9707 - loss: 0.1217
# Epoch 23: val_accuracy improved from 0.91026 to 0.94872, saving model to best_facial_recognition_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.9698 - loss: 0.1227 - val_accuracy: 0.9487 - val_loss: 0.4334 - learning_rate: 1.0000e-05
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9165 - loss: 0.1940
# Epoch 24: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9185 - loss: 0.1911 - val_accuracy: 0.8590 - val_loss: 0.5407 - learning_rate: 1.0000e-05
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9558 - loss: 0.1585
# Epoch 25: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9549 - loss: 0.1586 - val_accuracy: 0.8462 - val_loss: 0.4925 - learning_rate: 1.0000e-05
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9551 - loss: 0.1103
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 26: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9551 - loss: 0.1122 - val_accuracy: 0.9103 - val_loss: 0.4411 - learning_rate: 1.0000e-05
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9564 - loss: 0.1162
# Epoch 27: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.9578 - loss: 0.1151 - val_accuracy: 0.9103 - val_loss: 0.4313 - learning_rate: 5.0000e-06
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9493 - loss: 0.1310
# Epoch 28: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.9507 - loss: 0.1294 - val_accuracy: 0.8718 - val_loss: 0.3750 - learning_rate: 5.0000e-06
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9671 - loss: 0.1057
# Epoch 29: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 31s 3s/step - accuracy: 0.9672 - loss: 0.1052 - val_accuracy: 0.9103 - val_loss: 0.4370 - learning_rate: 5.0000e-06
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9737 - loss: 0.0974
# Epoch 30: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.9737 - loss: 0.0976 - val_accuracy: 0.8718 - val_loss: 0.3929 - learning_rate: 5.0000e-06
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9565 - loss: 0.1185
# Epoch 31: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 31: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9579 - loss: 0.1162 - val_accuracy: 0.8590 - val_loss: 0.4639 - learning_rate: 5.0000e-06
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9690 - loss: 0.0909
# Epoch 32: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.9692 - loss: 0.0909 - val_accuracy: 0.9103 - val_loss: 0.3943 - learning_rate: 2.5000e-06
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9645 - loss: 0.1182
# Epoch 33: val_accuracy did not improve from 0.94872
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.9636 - loss: 0.1194 - val_accuracy: 0.9103 - val_loss: 0.3829 - learning_rate: 2.5000e-06
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 23.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 863ms/step - accuracy: 0.8357 - loss: 0.5182
# Precisión de validación: 85.90%

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np

def predict_image(model, image_path, threshold=0.6):
    """
    Realiza la predicción de una imagen con el modelo entrenado y devuelve la clase predicha solo si la probabilidad es alta.

    Args:
        model (tf.keras.Model): El modelo entrenado
        image_path (str): Ruta a la imagen que se quiere predecir
        threshold (float): Umbral de probabilidad para considerar una predicción válida

    Returns:
        tuple: Clase predicha y su probabilidad, o None si no alcanza el umbral
    """
    # Cargar la imagen y preprocesarla
    img = image.load_img(image_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Expandir la dimensión para que sea un batch de tamaño 1
    img_array = img_array / 255.0  # Normalizar

    # Realizar la predicción
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)
    predicted_prob = predictions[0][predicted_class[0]]  # Obtener la probabilidad de la clase predicha

    # Verificar si la probabilidad es mayor que el umbral
    if predicted_prob < threshold:
        return None, None  # No hay predicción confiable

    # Obtener el nombre de la clase predicha
    predicted_class_name = list(train_data.class_indices.keys())[predicted_class[0]]

    return predicted_class_name, predicted_prob

# Ejemplo de predicción
img_path = '/content/drive/MyDrive/prueba/gato.jpg'
predicted_class, predicted_prob = predict_image(model, img_path)

if predicted_class is None:
    print("La imagen no pertenece a ninguna de las clases conocidas.")
else:
    print(f"Predicción: {predicted_class} con probabilidad de {predicted_prob*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicción: Juan con probabilidad de 60.57%

# %%
import tensorflow as tf

# Cargar el modelo entrenado
saved_model_path = 'best_facial_recognition_model.keras'
model = tf.keras.models.load_model(saved_model_path)

# Convertir el modelo a TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Guardar el modelo convertido en formato .tflite
tflite_model_path = 'model.tflite'
with open(tflite_model_path, 'wb') as f:
    f.write(tflite_model)

print(f"Modelo convertido a TensorFlow Lite y guardado en: {tflite_model_path}")
# Out:
# Saved artifact at '/tmp/tmpf9poaemp'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_23')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   134498142140048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497323820560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498345774848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497976089264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497323815456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498417129984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497327257152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497327255568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498141748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497327263664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497327262256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172929824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172930176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172933344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172931056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498143116400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497225272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172932992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497326493968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498172932112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224900128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224896608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224884288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224893440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224888864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224896080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224898016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224892384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224890976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224475744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224483664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224483488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224488240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224482784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224485776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224489824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224478736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224477856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224479968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224475216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224913344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224909120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224915280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224910176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224902960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224904368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224907536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224902608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224904720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497224902432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157578720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157583120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157579776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157582416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157585584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157585760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157590160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157586816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157589456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157592272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157660640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157658176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157658880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157659584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157664160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157668736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157665392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157668032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157672080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157672960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157671904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157674192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157671200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157727760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157727936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157732336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157728992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157731632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157734976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157739376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157736032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157738672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157736208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157824128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157828528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157825184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157827824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157831168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157831344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157835744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157832400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157835040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157832576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157889136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157893536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157890192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157892832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157896000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157896176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157900576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157899872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157902688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157903568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157971760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157903216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157970176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157974576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157974752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157979152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157975808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157978448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157981616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157981792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157982320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157983552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157984784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158038176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158038352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158042752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158039408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158042048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158045216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158045392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158049792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158046448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158049088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498158046624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156053776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156058176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156054832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156057472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156060816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156060992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156065392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156062048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156064688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156062224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156105040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156105392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156102576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156103280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156107856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156108032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156112432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156109088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156111728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156115952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156116832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156117184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156117712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156184320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156187840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156188016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156192416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156189072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156191712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156194880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156195056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156199456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156198752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156196288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156299360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156303760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156300416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156303056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156306224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156306400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156310800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156307456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156310096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156314144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156415280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156413872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156413520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156414224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156418976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156419152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156423552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156420208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156422848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156426896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156480640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156481520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156429008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156479056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156485920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156578240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156579120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156491728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156494016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156479936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156585104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156585280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156581408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156583696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156592848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156579472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156590208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156591440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156591616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156645888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156646064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156650464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156647120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156649760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156651696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156651872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156656272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156652928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156655568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156653104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156741024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156745424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156742080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156744720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156747888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156748064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156752464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156749120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156751760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156755984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156756336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156822944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156825056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156823472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156827872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156828048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156832448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156829104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156831744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156834912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156829280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156835616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156836848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156838432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156875088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156875264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156879664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156876320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156878960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156882128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156882304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156886704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156883360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156886000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157004224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157008624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157005280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157007920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157009856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157010032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157014432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157011088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498157013728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134497323821968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498345773968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155030384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155020352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498156480992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155029680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155033200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155451968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155454080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155455840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155453376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155454608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155460592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134498155627264: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo convertido a TensorFlow Lite y guardado en: model.tflite
